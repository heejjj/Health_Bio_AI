# %% [markdown]
# <a href="https://colab.research.google.com/github/heejjj/Health_Bio_AI/blob/bio_colab/0313_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame[{
    'col1' :[10,20,30],
    'col2' :['a','b','c']
}]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-1c243e743832> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.DataFrame[{
#       4     'col1' :[10,20,30],
#       5     'col2' :['a','b','c']
#
# TypeError: 'type' object is not subscriptable

# %%
pd.get_dummies(df)

# %%
df = pd.DataFrame({
    'col1':['001','002','003','004','005','006'],
    'col2':[10,20,30,40,50,60],
    'col3':['서울시','경기도','서울시','제주도','경기도','서울시']
})
df
# Out:
#   col1  col2 col3
# 0  001    10  서울시
# 1  002    20  경기도
# 2  003    30  서울시
# 3  004    40  제주도
# 4  005    50  경기도
# 5  006    60  서울시

# %%
#get_dummies: 수치를 바꿔주는 인코딩 작업
"""월요일을 1, 화요일을 2, 수요일을 3이라고 단순하게 수치형 데이터로 변환하게 되면 해당 데이터들 간
1+2 = 3이라는 관계성이 존재하게 된다. 

그러나 실제 데이터인 월요일, 화요일, 수요일 간에는 그러한 관계성이 없다!

따라서, 사실이 아닌 관계성으로 인해 잘못된 학습이 일어날 수 있으므로

서로 무관한 수, 즉 더미로 만든 가변수로 변환함으로서 그러한 문제를 막아준다!

판다스(pandas)에서는 손쉽게 더미의 가변수를 만들 수 있도록 get_dummies함수를 제공
"""

pd.get_dummies(df)
# Out:
#    col2  col1_001  col1_002  col1_003  col1_004  col1_005  col1_006  col3_경기도  \
# 0    10         1         0         0         0         0         0         0
# 1    20         0         1         0         0         0         0         1
# 2    30         0         0         1         0         0         0         0
# 3    40         0         0         0         1         0         0         0
# 4    50         0         0         0         0         1         0         1
# 5    60         0         0         0         0         0         1         0
#
#    col3_서울시  col3_제주도
# 0         1         0
# 1         0         0
# 2         1         0
# 3         0         1
# 4         0         0
# 5         1         0

# %%
kbo=pd.read_csv('https://raw.githubusercontent.com/Youngpyoryu/Lecture_Note/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC/kbo.csv')
kbo
# Out:
#       연도  순위    팀  경기수   승   패  무     승률   게임차
# 0   2019   1   두산  144  88  55  1  0.615   0.0
# 1   2019   2   키움  144  86  57  1  0.601   2.0
# 2   2019   3   SK  144  88  55  1  0.615   0.0
# 3   2019   4   LG  144  79  64  1  0.552   9.0
# 4   2019   5   NC  144  73  69  2  0.514  14.5
# 5   2019   6   KT  144  71  71  2  0.500  16.5
# 6   2019   7  KIA  144  62  80  2  0.437  25.5
# 7   2019   8   삼성  144  60  83  1  0.420  28.0
# 8   2019   9   한화  144  58  86  0  0.403  30.5
# 9   2019  10   롯데  144  48  93  3  0.340  39.0
# 10  2018   1   두산  144  93  51  0  0.646 -14.5
# 11  2018   2   SK  144  78  65  1  0.545   0.0
# 12  2018   3   한화  144  77  67  0  0.535   1.5
# 13  2018   4   넥센  144  75  69  0  0.521   3.5
# 14  2018   5  KIA  144  70  74  0  0.486   8.5
# 15  2018   5   삼성  144  68  72  4  0.486   8.5
# 16  2018   7   롯데  144  68  74  2  0.479   9.5
# 17  2018   8   LG  144  68  75  1  0.476  10.0
# 18  2018   9   KT  144  59  82  3  0.418  18.0
# ...

# %%
kbo.shape
# Out:
# (30, 9)

# %%
kbo.columns
# Out:
# Index(['연도', '순위', '팀', '경기수', '승', '패', '무', '승률', '게임차'], dtype='object')

# %%
kbo.describe()
# Out:
#                 연도         순위    경기수          승          패          무  \
# count    30.000000  30.000000   30.0  30.000000  30.000000  30.000000
# mean   2018.000000   5.466667  144.0  71.200000  71.200000   1.600000
# std       0.830455   2.921187    0.0  11.871147  11.591912   1.275769
# min    2017.000000   1.000000  144.0  48.000000  51.000000   0.000000
# 25%    2017.000000   3.000000  144.0  61.250000  62.500000   1.000000
# 50%    2018.000000   5.000000  144.0  70.500000  71.500000   1.000000
# 75%    2019.000000   8.000000  144.0  79.000000  80.750000   2.000000
# max    2019.000000  10.000000  144.0  93.000000  94.000000   5.000000
#
#               승률        게임차
# count  30.000000  30.000000
# mean    0.499800  12.833333
# std     0.082079  12.576204
# min     0.340000 -14.500000
# 25%     0.431750   2.375000
# 50%     0.494500   9.750000
# 75%     0.558000  19.500000
# max     0.646000  39.000000

# %%
kbo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      30 non-null     int64
#  1   순위      30 non-null     int64
#  2   팀       30 non-null     object
#  3   경기수     30 non-null     int64
#  4   승       30 non-null     int64
#  5   패       30 non-null     int64
#  6   무       30 non-null     int64
#  7   승률      30 non-null     float64
#  8   게임차     30 non-null     float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 2.2+ KB

# %%
kbo.isna().sum()
# Out:
# 연도     0
# 순위     0
# 팀      0
# 경기수    0
# 승      0
# 패      0
# 무      0
# 승률     0
# 게임차    0
# dtype: int64

# %%
kbo.groupby('팀')

# %%
kbo.groupby('팀').count()
#넥센이 키움으로 바뀜(도메인 지식 필요)
# Out:
#      연도  순위  경기수  승  패  무  승률  게임차
# 팀
# KIA   3   3    3  3  3  3   3    3
# KT    3   3    3  3  3  3   3    3
# LG    3   3    3  3  3  3   3    3
# NC    3   3    3  3  3  3   3    3
# SK    3   3    3  3  3  3   3    3
# 넥센    2   2    2  2  2  2   2    2
# 두산    3   3    3  3  3  3   3    3
# 롯데    3   3    3  3  3  3   3    3
# 삼성    3   3    3  3  3  3   3    3
# 키움    1   1    1  1  1  1   1    1
# 한화    3   3    3  3  3  3   3    3

# %%
kbo.groupby(['연도','팀']).sum()
# Out:
#           순위  경기수   승   패  무     승률   게임차
# 연도   팀
# 2017 KIA   1  144  87  56  1  0.608   0.0
#      KT   10  144  50  94  0  0.347  37.5
#      LG    6  144  69  72  3  0.489  17.0
#      NC    4  144  79  62  3  0.560   7.0
#      SK    5  144  75  68  1  0.524  12.0
#      넥센    7  144  69  73  2  0.486  17.5
#      두산    2  144  84  57  3  0.596   2.0
#      롯데    3  144  80  62  2  0.563   6.5
#      삼성    9  144  55  84  5  0.396  30.0
#      한화    8  144  61  81  2  0.430  25.5
# 2018 KIA   5  144  70  74  0  0.486   8.5
#      KT    9  144  59  82  3  0.418  18.0
#      LG    8  144  68  75  1  0.476  10.0
#      NC   10  144  58  85  1  0.406  20.0
#      SK    2  144  78  65  1  0.545   0.0
#      넥센    4  144  75  69  0  0.521   3.5
#      두산    1  144  93  51  0  0.646 -14.5
#      롯데    7  144  68  74  2  0.479   9.5
#      삼성    5  144  68  72  4  0.486   8.5
#      한화    3  144  77  67  0  0.535   1.5
# 2019 KIA   7  144  62  80  2  0.437  25.5
# ...

# %%
kbo.groupby('팀')['승률'].max()
# Out:
# 팀
# KIA    0.608
# KT     0.500
# LG     0.552
# NC     0.560
# SK     0.615
# 넥센     0.521
# 두산     0.646
# 롯데     0.563
# 삼성     0.486
# 키움     0.601
# 한화     0.535
# Name: 승률, dtype: float64

# %%
kbo.groupby(['연도','팀'])['승률','순위'].max()
# Out:
# <ipython-input-16-668da1a288a7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   kbo.groupby(['연도','팀'])['승률','순위'].max()
#              승률  순위
# 연도   팀
# 2017 KIA  0.608   1
#      KT   0.347  10
#      LG   0.489   6
#      NC   0.560   4
#      SK   0.524   5
#      넥센   0.486   7
#      두산   0.596   2
#      롯데   0.563   3
#      삼성   0.396   9
#      한화   0.430   8
# 2018 KIA  0.486   5
#      KT   0.418   9
#      LG   0.476   8
#      NC   0.406  10
#      SK   0.545   2
#      넥센   0.521   4
#      두산   0.646   1
#      롯데   0.479   7
#      삼성   0.486   5
#      한화   0.535   3
# 2019 KIA  0.437   7
#      KT   0.500   6
#      LG   0.552   4
#      NC   0.514   5
#      SK   0.615   3
#      두산   0.615   1
#      롯데   0.340  10
#      삼성   0.420   8
#      키움   0.601   2
#      한화   0.403   9

# %%
grouped = kbo.groupby('팀')
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for name,group in grouped:
    print(name)
    print(group)

    print('-'*50)
# Out:
# KIA
#       연도  순위    팀  경기수   승   패  무     승률   게임차
# 6   2019   7  KIA  144  62  80  2  0.437  25.5
# 14  2018   5  KIA  144  70  74  0  0.486   8.5
# 20  2017   1  KIA  144  87  56  1  0.608   0.0
# --------------------------------------------------
# KT
#       연도  순위   팀  경기수   승   패  무     승률   게임차
# 5   2019   6  KT  144  71  71  2  0.500  16.5
# 18  2018   9  KT  144  59  82  3  0.418  18.0
# 29  2017  10  KT  144  50  94  0  0.347  37.5
# --------------------------------------------------
# LG
#       연도  순위   팀  경기수   승   패  무     승률   게임차
# 3   2019   4  LG  144  79  64  1  0.552   9.0
# 17  2018   8  LG  144  68  75  1  0.476  10.0
# 25  2017   6  LG  144  69  72  3  0.489  17.0
# --------------------------------------------------
# NC
#       연도  순위   팀  경기수   승   패  무     승률   게임차
# 4   2019   5  NC  144  73  69  2  0.514  14.5
# 19  2018  10  NC  144  58  85  1  0.406  20.0
# 23  2017   4  NC  144  79  62  3  0.560   7.0
# ...

# %%
grouped.get_group('한화')
# Out:
#       연도  순위   팀  경기수   승   패  무     승률   게임차
# 8   2019   9  한화  144  58  86  0  0.403  30.5
# 12  2018   3  한화  144  77  67  0  0.535   1.5
# 27  2017   8  한화  144  61  81  2  0.430  25.5

# %% [markdown]
# 그룹별로 특정한 집계함수로 적용.

# %%
grouped['순위'].agg([('함수', lambda val : val.max()-val.min())])
# Out:
#      함수
# 팀
# KIA   6
# KT    4
# LG    4
# NC    6
# SK    3
# 넥센    3
# 두산    1
# 롯데    7
# 삼성    4
# 키움    0
# 한화    6

# %%
import numpy as np
grouped.agg({'순위':np.mean, '승률':[np.mean, np.std]})
# Out:
#            순위        승률
#          mean      mean       std
# 팀
# KIA  4.333333  0.510333  0.088059
# KT   8.333333  0.421667  0.076566
# LG   6.000000  0.505667  0.040649
# NC   6.333333  0.493333  0.079053
# SK   3.333333  0.561333  0.047648
# 넥센   5.500000  0.503500  0.024749
# 두산   1.333333  0.619000  0.025239
# 롯데   6.666667  0.460667  0.112625
# 삼성   7.333333  0.434000  0.046605
# 키움   2.000000  0.601000       NaN
# 한화   6.666667  0.456000  0.069735

# %%
kbo.groupby('팀').filter(lambda x:len(x)==1)
?
# Out:
#      연도  순위   팀  경기수   승   패  무     승률  게임차
# 1  2019   2  키움  144  86  57  1  0.601  2.0

# %% [markdown]
# - 판다스 인 액션을 참고
#  - 셜록 홈즈는 아서 코난 도일의 첫 번째 고전 단편 소설 <보헤미아 왕국의 스캔들>에서 조수인 존 왓슨에게 이렇게 조언합니다. "데이터를 얻기 전에 이론부터 세우는 것은 중대한 실수입니다. 사실에 맞는 이론을 세우지 않고 이론에 맞게 사실을 왜곡하는 것은 아주 어리석은 일이죠."

# %% [markdown]
#  - 데이터 랭글링 : 다양한 데이터 소스의 데이터를 통합하고 쉽게 액세스하고 분석할 수 있도록 정리하는 프로세스.

# %%
import pandas as pd
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/paskhaver/pandas-in-action/master/chapter_01_introducing_pandas/movies.csv', index_col='Title')
df
# 향과 열을 안꺼번에 쓴것
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/paskhaver/pandas-in-action/master/chapter_01_introducing_pandas/movies.csv', index_col='Title')
df
#행과열을 구별한것?
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
df.head()
# Out:
#                               Rank       Studio       Gross  Year
# Title
# Avengers: Endgame                1  Buena Vista  $2,796.30   2019
# Avatar                           2          Fox  $2,789.70   2009
# Titanic                          3    Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4  Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5  Buena Vista  $2,048.40   2018

# %%
df.tail()
# Out:
#                           Rank           Studio     Gross  Year
# Title
# Yogi Bear                  778  Warner Brothers  $201.60   2010
# Garfield: The Movie        779              Fox  $200.80   2004
# Cats & Dogs                780  Warner Brothers  $200.70   2001
# The Hunt for Red October   781        Paramount  $200.50   1990
# Valkyrie                   782              MGM  $200.30   2008

# %%
df['Title'] #인덱스로 되어 있어서 오류가 난다.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Title'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df[0:]
# Out:
#                               Rank           Studio       Gross  Year
# Title
# Avengers: Endgame                1      Buena Vista  $2,796.30   2019
# Avatar                           2              Fox  $2,789.70   2009
# Titanic                          3        Paramount  $2,187.50   1997
# Star Wars: The Force Awakens     4      Buena Vista  $2,068.20   2015
# Avengers: Infinity War           5      Buena Vista  $2,048.40   2018
# ...                            ...              ...         ...   ...
# Yogi Bear                      778  Warner Brothers    $201.60   2010
# Garfield: The Movie            779              Fox    $200.80   2004
# Cats & Dogs                    780  Warner Brothers    $200.70   2001
# The Hunt for Red October       781        Paramount    $200.50   1990
# Valkyrie                       782              MGM    $200.30   2008
#
# [782 rows x 4 columns]

# %%
#label이기 때문에 loc으로 접근 
df.loc['Avatar']
# Out:
# Rank               2
# Studio           Fox
# Gross     $2,789.70
# Year            2009
# Name: Avatar, dtype: object

# %%
len(df)
# Out:
# 782

# %%
df.size
# Out:
# 3128

# %%
#info> type> types 활용도 

df.dtypes
# Out:
# Rank       int64
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 782 entries, Avengers: Endgame to Valkyrie
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    782 non-null    int64
#  1   Studio  782 non-null    object
#  2   Gross   782 non-null    object
#  3   Year    782 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 46.7+ KB

# %%
#500번째 영화를 꺼내보세요

# %%
df.iloc[499]
# Out:
# Rank           500
# Studio         Fox
# Gross     $288.30
# Year          2018
# Name: Maze Runner: The Death Cure, dtype: object

# %%
df.loc["Forrest Gump"]
# Out:
# Rank            119
# Studio    Paramount
# Gross      $677.90
# Year           1994
# Name: Forrest Gump, dtype: object

# %% [markdown]
# - 인덱스를 중복을 허락할까?
#  -인덱스 레이블에는 중복 항목이 있을 수 있음음

# %%
df.loc["101 Dalmatians"]
#label은 사람이 붙이는거기 때문에 임의로 허용할 수 있다. 
#index는 중복 허락 X
# Out:
#                 Rank       Studio     Gross  Year
# Title
# 101 Dalmatians   425  Buena Vista  $320.70   1996
# 101 Dalmatians   708  Buena Vista  $215.90   1961

# %%
#sieres = list + dic

# %%
# sort_values() -> year 오름차순으로 정렬 

df.sort_values(by = 'Year', ascending = True).head()

#ascending = False 내림차순
# Out:
#                     Rank       Studio     Gross  Year
# Title
# Gone with the Wind   288          MGM  $402.40   1939
# Bambi                540          RKO  $267.40   1942
# 101 Dalmatians       708  Buena Vista  $215.90   1961
# The Jungle Book      755  Buena Vista  $205.80   1967
# The Godfather        604    Paramount  $245.10   1972

# %%
df.sort_values(by=['Studio', 'Year']).head()
# Out:
#                          Rank       Studio     Gross  Year
# Title
# The Blair Witch Project   588      Artisan  $248.60   1999
# 101 Dalmatians            708  Buena Vista  $215.90   1961
# The Jungle Book           755  Buena Vista  $205.80   1967
# Who Framed Roger Rabbit   410  Buena Vista  $329.80   1988
# Dead Poets Society        636  Buena Vista  $235.90   1989

# %%
df.sort_index().head()
# Out:
#                   Rank           Studio     Gross  Year
# Title
# 10,000 B.C.        536  Warner Brothers  $269.80   2008
# 101 Dalmatians     708      Buena Vista  $215.90   1961
# 101 Dalmatians     425      Buena Vista  $320.70   1996
# 2 Fast 2 Furious   632        Universal  $236.40   2003
# 2012                93             Sony  $769.70   2009

# %%
df['Studio'].value_counts().head(10)
# Out:
# Warner Brothers    132
# Buena Vista        125
# Fox                117
# Universal          109
# Sony                86
# Paramount           76
# Dreamworks          27
# Lionsgate           21
# New Line            16
# MGM                 11
# Name: Studio, dtype: int64

# %% [markdown]
# - 하나 이상의 기준으로 열 필터링링

# %%
df['Studio'] == 'Universal'
# Out:
# Title
# Avengers: Endgame               False
# Avatar                          False
# Titanic                         False
# Star Wars: The Force Awakens    False
# Avengers: Infinity War          False
#                                 ...
# Yogi Bear                       False
# Garfield: The Movie             False
# Cats & Dogs                     False
# The Hunt for Red October        False
# Valkyrie                        False
# Name: Studio, Length: 782, dtype: bool

# %%
df[df['Studio'] == 'Universal']
# Out:
#                                 Rank     Studio       Gross  Year
# Title
# Jurassic World                     6  Universal  $1,671.70   2015
# Furious 7                          8  Universal  $1,516.00   2015
# Jurassic World: Fallen Kingdom    13  Universal  $1,309.50   2018
# The Fate of the Furious           17  Universal  $1,236.00   2017
# Minions                           19  Universal  $1,159.40   2015
# ...                              ...        ...         ...   ...
# The Break-Up                     763  Universal    $205.00   2006
# Everest                          766  Universal    $203.40   2015
# Patch Adams                      772  Universal    $202.30   1998
# Kindergarten Cop                 775  Universal    $202.00   1990
# Straight Outta Compton           776  Universal    $201.60   2015
#
# [109 rows x 4 columns]

# %% [markdown]
# - 2015년도에 개봉한 영화를 필터링 하시오(Universal만)

# %%
df[[df["Year"] == 2015], and df[df['Studio']==['Universal']]]
# Out:
#   File "<ipython-input-73-4dcd07d2338f>", line 1
#     df[[df["Year"] == 2015], and df[df['Studio']==['Universal']]]
#                              ^
# SyntaxError: invalid syntax

# %%
df2 =df_sort_values(by=['Year','Stuio'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-d673cad85c0d> in <module>
# ----> 1 df2 =df_sort_values(by=['Year','Stuio'])
#
# NameError: name 'df_sort_values' is not defined

# %%
df[df'Studio']== 'Universal'] & [df[df'[Year'] == 2015]
# Out:
#   File "<ipython-input-82-37e07d05c40d>", line 1
#     df[df'Studio']== 'Universal'] & [df[df'[Year'] == 2015]
#          ^
# SyntaxError: invalid syntax

# %%
df[df['Studio']== 'Universal']
# Out:
#                                 Rank     Studio       Gross  Year
# Title
# Jurassic World                     6  Universal  $1,671.70   2015
# Furious 7                          8  Universal  $1,516.00   2015
# Jurassic World: Fallen Kingdom    13  Universal  $1,309.50   2018
# The Fate of the Furious           17  Universal  $1,236.00   2017
# Minions                           19  Universal  $1,159.40   2015
# ...                              ...        ...         ...   ...
# The Break-Up                     763  Universal    $205.00   2006
# Everest                          766  Universal    $203.40   2015
# Patch Adams                      772  Universal    $202.30   1998
# Kindergarten Cop                 775  Universal    $202.00   1990
# Straight Outta Compton           776  Universal    $201.60   2015
#
# [109 rows x 4 columns]

# %%
# 해답 (교집함을 가져와라라)

released_by_universal = df['Studio'] == 'Universal'
released_in_2015 = df['Year'] == 2015
df[released_by_universal & released_in_2015]
# Out:
#                         Rank     Studio       Gross  Year
# Title
# Jurassic World             6  Universal  $1,671.70   2015
# Furious 7                  8  Universal  $1,516.00   2015
# Minions                   19  Universal  $1,159.40   2015
# Fifty Shades of Grey     165  Universal    $571.00   2015
# Pitch Perfect 2          504  Universal    $287.50   2015
# Ted 2                    702  Universal    $216.70   2015
# Everest                  766  Universal    $203.40   2015
# Straight Outta Compton   776  Universal    $201.60   2015

# %% [markdown]
# - 1975년 전의 것 을 조회해 보자자

# %%
before_1975 = df['Year'] <= 1975

# %%
before_1975
# Out:
# Title
# Avengers: Endgame               False
# Avatar                          False
# Titanic                         False
# Star Wars: The Force Awakens    False
# Avengers: Infinity War          False
#                                 ...
# Yogi Bear                       False
# Garfield: The Movie             False
# Cats & Dogs                     False
# The Hunt for Red October        False
# Valkyrie                        False
# Name: Year, Length: 782, dtype: bool

# %%
df[df['Year']<=1975]
# Out:
#                     Rank           Studio     Gross  Year
# Title
# Jaws                 228        Universal  $470.70   1975
# The Exorcist         252  Warner Brothers  $441.30   1973
# Gone with the Wind   288              MGM  $402.40   1939
# Bambi                540              RKO  $267.40   1942
# The Godfather        604        Paramount  $245.10   1972
# 101 Dalmatians       708      Buena Vista  $215.90   1961
# The Jungle Book      755      Buena Vista  $205.80   1967

# %%
df[df['Year']<1975]
# Out:
#                     Rank           Studio     Gross  Year
# Title
# The Exorcist         252  Warner Brothers  $441.30   1973
# Gone with the Wind   288              MGM  $402.40   1939
# Bambi                540              RKO  $267.40   1942
# The Godfather        604        Paramount  $245.10   1972
# 101 Dalmatians       708      Buena Vista  $215.90   1961
# The Jungle Book      755      Buena Vista  $205.80   1967

# %% [markdown]
# - 1983년에서 1986년 사이에 개봉한 영화를 필터링하는 예제제

# %%
df["Year"].between(1983, 1986)
# Out:
# Title
# Avengers: Endgame               False
# Avatar                          False
# Titanic                         False
# Star Wars: The Force Awakens    False
# Avengers: Infinity War          False
#                                 ...
# Yogi Bear                       False
# Garfield: The Movie             False
# Cats & Dogs                     False
# The Hunt for Red October        False
# Valkyrie                        False
# Name: Year, Length: 782, dtype: bool

# %%
df[df["Year"].between(1983, 1986)]
# Out:
#                                       Rank     Studio     Gross  Year
# Title
# Return of the Jedi                     222        Fox  $475.10   1983
# Back to the Future                     311  Universal  $381.10   1985
# Top Gun                                357  Paramount  $356.80   1986
# Indiana Jones and the Temple of Doom   403  Paramount  $333.10   1984
# Crocodile Dundee                       413  Paramount  $328.20   1986
# Beverly Hills Cop                      432  Paramount  $316.40   1984
# Rocky IV                               467        MGM  $300.50   1985
# Rambo: First Blood Part II             469    TriStar  $300.40   1985
# Ghostbusters                           485   Columbia  $295.20   1984
# Out of Africa                          662  Universal  $227.50   1985

# %%
#between 없이 조회하기 

df[df['Year']>1983  and df['Year'] <1986]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-960476291f74> in <module>
#       1 #between 없이 조회하기
#       2
# ----> 3 df[df['Year']>1983  and df['Year'] <1986]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[ (df['Year']>1983) & (df['Year']<1986)]
# Out:
#                                       Rank     Studio     Gross  Year
# Title
# Back to the Future                     311  Universal  $381.10   1985
# Indiana Jones and the Temple of Doom   403  Paramount  $333.10   1984
# Beverly Hills Cop                      432  Paramount  $316.40   1984
# Rocky IV                               467        MGM  $300.50   1985
# Rambo: First Blood Part II             469    TriStar  $300.40   1985
# Ghostbusters                           485   Columbia  $295.20   1984
# Out of Africa                          662  Universal  $227.50   1985

# %% [markdown]
#  - 인덱스에서 영화 제목을 소문자로 바꾸고 제목에 'dark'라는 단어가 있는 모든 영화를 찾는 예제

# %%
df.index.str.lower().str.contains('dark')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
df[df.index.str.lower().str.contains('dark')]
# Out:
#                                 Rank           Studio       Gross  Year
# Title
# Transformers: Dark of the Moon    23        Paramount  $1,123.80   2011
# The Dark Knight Rises             27  Warner Brothers  $1,084.90   2012
# The Dark Knight                   39  Warner Brothers  $1,004.90   2008
# Thor: The Dark World             132      Buena Vista    $644.60   2013
# Star Trek Into Darkness          232        Paramount    $467.40   2013
# Fifty Shades Darker              309        Universal    $381.50   2017
# Dark Shadows                     600  Warner Brothers    $245.50   2012
# Dark Phoenix                     603              Fox    $245.10   2019

# %%
df.index.str.lower().str.contains
# Out:
# <bound method StringMethods.contains of <pandas.core.strings.accessor.StringMethods object at 0x7fe171d04640>>

# %% [markdown]
# - 어떤 제작사가 제작한 영화의 총 수익이 가장 높을까?
#  - 열의값을 십진수로 변환하려면 두가지 기호 $,,을 모두 제거하고 빈 텍스트로 바꾸어야 함

# %%
df['Gross'].str.replace('$', '' , regex = False).str.replace(',', '', regex = False)
# Out:
# Title
# Avengers: Endgame               2796.30
# Avatar                          2789.70
# Titanic                         2187.50
# Star Wars: The Force Awakens    2068.20
# Avengers: Infinity War          2048.40
#                                   ...
# Yogi Bear                        201.60
# Garfield: The Movie              200.80
# Cats & Dogs                      200.70
# The Hunt for Red October         200.50
# Valkyrie                         200.30
# Name: Gross, Length: 782, dtype: object

# %%
df['Gross'] = (
    df['Gross']
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    
)

# %%
df['Gross'] = (df['Gross']
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .astype(float)
    
)

# %% [markdown]
# 1)정규 표현식 문법
#
#
# <figure>
# <img src = 'https://miro.medium.com/max/700/1*Y-q0dkUClSW0dX6uuysnJQ.png'>
# <figure>
#
# <figure>
# <img src = 'https://miro.medium.com/max/700/1*c__WeRlFyGY_-7LeKQkNnQ.png'>
# <figure>

# %%
# 정규표현식

# %%
import re
r = re.compile("a.c") # a와 c사이에 어떤 1개라도 문자가 올수 있음.
r.search("kkk")
# 아무런 결과도 출력되지 않는다.
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r.search("abbc")

# %%
r = re.compile('^a')
r.research('bbc')

# %%
r.search('ab')

# %%
r.search('abbbbbbbbbbbbbbbbbbbbbbbbbbb')

# %%
r = re.compile('^[abc]')
r.search('zzzz')

# %%
df['Gross'].mean()
# Out:
# 439.0308184143222

# %%
df['Studio'].sort_values(by = df['Gross'], ascending = True)


#df.sort_values(by = 'Year', ascending = True).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-1f014f31d760> in <module>
# ----> 1 df['Studio'].sort_values(by = df['Gross'], ascending = True)
#       2
#       3
#       4 #df.sort_values(by = 'Year', ascending = True).head()
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() got an unexpected keyword argument 'by'

# %% [markdown]
#  - 정규표현식
#  -특정한 규칙을 가진 문자열의 집합을 표현하는데 사용하는 형식 언어
#  -문자열의 검색과 치환을 위한 용도로 쓰임.

# %% [markdown]
# 1)정규 표현식 문법
#
#
# <figure>
# <img src = 'https://miro.medium.com/max/700/1*Y-q0dkUClSW0dX6uuysnJQ.png'>
# <figure>
#
# <figure>
# <img src = 'https://miro.medium.com/max/700/1*c__WeRlFyGY_-7LeKQkNnQ.png'>
# <figure>

# %%
import re
r = re.compile("a.c") # a와 c사이에 어떤 1개라도 문자가 올수 있음.
r.search("kkk")
# 아무런 결과도 출력되지 않는다.
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r.search("abbc")

# %%
r = re.compile('^a')
r.search('bbc')

# %%
r.search('abbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
r = re.compile('^[abc]')
r.search('zzzz')

# %%
r = re.compile('^[abc]')
r.search('a')
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
r = re.compile('^[abc]')
r.search('b')
# Out:
# <re.Match object; span=(0, 1), match='b'>

# %%
text = """이름 : 김철수
전화번호 : 010 - 1234 - 1234
나이 : 30
성별 : 남"""
re.findall("\d+", text)
# Out:
# ['010', '1234', '1234', '30']

# %%
text="Regular expression : A regular expression, regex or regexp[1] (sometimes called a rational expression)[2][3] is, in theoretical computer science and formal language theory, a sequence of characters that define a search pattern."
re.sub('[^a-zA-Z]',' ',text)
# Out:
# 'Regular expression   A regular expression  regex or regexp     sometimes called a rational expression        is  in theoretical computer science and formal language theory  a sequence of characters that define a search pattern '

# %% [markdown]
# - Q) 영화 제작사 당 총 흥행 수익 계산

# %%
df.head()
# Out:
#                               Rank       Studio   Gross  Year
# Title
# Avengers: Endgame                1  Buena Vista  2796.3  2019
# Avatar                           2          Fox  2789.7  2009
# Titanic                          3    Paramount  2187.5  1997
# Star Wars: The Force Awakens     4  Buena Vista  2068.2  2015
# Avengers: Infinity War           5  Buena Vista  2048.4  2018

# %%
df['Gross'].str.replace(
    '$','',regex=False
).str.replace(',','',regex=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-7919c63e6af0> in <module>
# ----> 1 df['Gross'].str.replace(
#       2     '$','',regex=False
#       3 ).str.replace(',','',regex=False)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df['Gross']= (
    df['Gross']
    .str.replace('$','',regex=False)
    .str.replace(',','',regex=False)
    .astype(float)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-fd24a4eca39a> in <module>
#       1 df['Gross']= (
# ----> 2     df['Gross']
#       3     .str.replace('$','',regex=False)
#       4     .str.replace(',','',regex=False)
#       5     .astype(float)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
# ...

# %%
studios = df.groupby('Studio')

# %%
studios['Gross'].count().sort_values(ascending = False).head()
# Out:
# Studio
# Warner Brothers    132
# Buena Vista        125
# Fox                117
# Universal          109
# Sony                86
# Name: Gross, dtype: int64

# %%
studios['Gross'].sum().head()
# Out:
# Studio
# Artisan                     248.6
# Buena Vista               73585.0
# CL                          228.1
# China Film Corporation      699.8
# Columbia                   1276.6
# Name: Gross, dtype: float64

# %%
studios['Gross'].sum().sort_values(ascending = False).head()
# Out:
# Studio
# Buena Vista        73585.0
# Warner Brothers    58643.8
# Fox                50420.8
# Universal          44302.3
# Sony               32822.5
# Name: Gross, dtype: float64

# %%
! python --version
# Out:
# Python 3.9.16

# %%
import pandas as pd
nba = pd.read_csv("https://raw.githubusercontent.com/paskhaver/pandas-in-action/master/chapter_04_the_dataframe_object/nba.csv",parse_dates = ["Birthday"])

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      450 non-null    object
#  1   Team      450 non-null    object
#  2   Position  450 non-null    object
#  3   Birthday  450 non-null    datetime64[ns]
#  4   Salary    450 non-null    int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 17.7+ KB

# %%
nba.head()
# Out:
#              Name                Team Position   Birthday   Salary
# 0    Shake Milton  Philadelphia 76ers       SG 1996-09-26  1445697
# 1  Christian Wood     Detroit Pistons       PF 1995-09-27  1645357
# 2   PJ Washington   Charlotte Hornets       PF 1998-08-23  3831840
# 3    Derrick Rose     Detroit Pistons       PG 1988-10-04  7317074
# 4   Marial Shayok  Philadelphia 76ers        G 1995-07-26    79568

# %%
nba.sample(5)
# Out:
#                  Name                    Team Position   Birthday    Salary
# 43       Jamal Murray          Denver Nuggets       PG 1997-02-23   4444746
# 279    Henry Ellenson           Brooklyn Nets       PF 1997-01-13     79568
# 185         Ky Bowman   Golden State Warriors       PG 1997-06-16     79568
# 183  Hassan Whiteside  Portland Trail Blazers        C 1989-06-13  27093018
# 136   Sekou Doumbouya         Detroit Pistons       SF 2000-12-23   3285120

# %%
nba.nunique()
# Out:
# Name        450
# Team         30
# Position      9
# Birthday    430
# Salary      269
# dtype: int64

# %%
nba.nlargest(n=4, columns = 'Salary')
# Out:
#                   Name                   Team Position   Birthday    Salary
# 205      Stephen Curry  Golden State Warriors       PG 1988-03-14  40231758
# 38          Chris Paul  Oklahoma City Thunder       PG 1985-05-06  38506482
# 219  Russell Westbrook        Houston Rockets       PG 1988-11-12  38506482
# 251          John Wall     Washington Wizards       PG 1990-09-06  38199000

# %%
nba.nsmallest(n=4, columns = 'Salary')
# Out:
#              Name                    Team Position   Birthday  Salary
# 4   Marial Shayok      Philadelphia 76ers        G 1995-07-26   79568
# 12   Norvel Pelle      Philadelphia 76ers       FC 1993-02-03   79568
# 24   Jaylen Hoard  Portland Trail Blazers       SF 1999-03-30   79568
# 25     Tyler Cook     Cleveland Cavaliers       PF 1997-09-23   79568

# %%
nba.describe()  #salary data type만 int라서 describe 할때 salary만 나옴 / 나머지는 다 obj라서 안나옴
# Out:
#              Salary
# count  4.500000e+02
# mean   7.653584e+06
# std    9.288810e+06
# min    7.956800e+04
# 25%    1.618520e+06
# 50%    3.303074e+06
# 75%    1.012957e+07
# max    4.023176e+07

# %%
nba['Salary'].describe()

# %%
nba.sum(numeric_only = True)
# Out:
# Salary    3444112694
# dtype: int64

# %%
nba.mean(numeric_only = True)  #평균
# Out:
# Salary    7.653584e+06
# dtype: float64

# %%
nba.median(numeric_only = True) #중앙값
# Out:
# Salary    3303074.5
# dtype: float64

# %%
nba.mode(numeric_only = True) #최빈값
# Out:
#    Salary
# 0   79568

# %%
nba.sort_values('Name')
nba.sort_values(by='Name')
# Out:
#                   Name                   Team Position   Birthday    Salary
# 52        Aaron Gordon          Orlando Magic       PF 1995-09-16  19863636
# 101      Aaron Holiday         Indiana Pacers       PG 1996-09-30   2239200
# 437        Abdel Nader  Oklahoma City Thunder       SF 1993-09-25   1618520
# 81         Adam Mokoka          Chicago Bulls        G 1998-07-18     79568
# 399  Admiral Schofield     Washington Wizards       SF 1997-03-30   1000000
# ..                 ...                    ...      ...        ...       ...
# 159        Zach LaVine          Chicago Bulls       PG 1995-03-10  19500000
# 302       Zach Norvell     Los Angeles Lakers       SG 1997-12-09     79568
# 312       Zhaire Smith     Philadelphia 76ers       SG 1999-06-04   3058800
# 137    Zion Williamson   New Orleans Pelicans        F 2000-07-06   9757440
# 248     Zylan Cheatham   New Orleans Pelicans       SF 1995-11-17     79568
#
# [450 rows x 5 columns]

# %%
nba.sort_values(by=['Team','Name'])
# Out:
#                 Name                Team Position   Birthday    Salary
# 359         Alex Len       Atlanta Hawks        C 1993-06-16   4160000
# 167     Allen Crabbe       Atlanta Hawks       SG 1992-04-09  18500000
# 276  Brandon Goodwin       Atlanta Hawks       PG 1995-10-02     79568
# 438   Bruno Fernando       Atlanta Hawks        C 1998-08-15   1400000
# 194      Cam Reddish       Atlanta Hawks       SF 1999-09-01   4245720
# ..               ...                 ...      ...        ...       ...
# 418     Jordan McRae  Washington Wizards       PG 1991-03-28   1645357
# 273  Justin Robinson  Washington Wizards       PG 1997-10-12    898310
# 428    Moritz Wagner  Washington Wizards        C 1997-04-26   2063520
# 21     Rui Hachimura  Washington Wizards       PF 1998-02-08   4469160
# 36     Thomas Bryant  Washington Wizards        C 1997-07-31   8000000
#
# [450 rows x 5 columns]

# %%
nba.sort_values(
    by=['Team', 'Salary'],
    ascending = [True, False])
# Out:
#                   Name                Team Position   Birthday    Salary
# 111   Chandler Parsons       Atlanta Hawks       SF 1988-10-25  25102512
# 28         Evan Turner       Atlanta Hawks       PG 1988-10-27  18606556
# 167       Allen Crabbe       Atlanta Hawks       SG 1992-04-09  18500000
# 213    De'Andre Hunter       Atlanta Hawks       SF 1997-12-02   7068360
# 339      Jabari Parker       Atlanta Hawks       PF 1995-03-15   6500000
# ..                 ...                 ...      ...        ...       ...
# 80         Isaac Bonga  Washington Wizards       PG 1999-11-08   1416852
# 399  Admiral Schofield  Washington Wizards       SF 1997-03-30   1000000
# 273    Justin Robinson  Washington Wizards       PG 1997-10-12    898310
# 283   Garrison Mathews  Washington Wizards       SG 1996-10-24     79568
# 353      Chris Chiozza  Washington Wizards       PG 1995-11-21     79568
#
# [450 rows x 5 columns]

# %%
nba.sort_index(axis=1).head()
# Out:
#     Birthday            Name Position   Salary                Team
# 0 1996-09-26    Shake Milton       SG  1445697  Philadelphia 76ers
# 1 1995-09-27  Christian Wood       PF  1645357     Detroit Pistons
# 2 1998-08-23   PJ Washington       PF  3831840   Charlotte Hornets
# 3 1988-10-04    Derrick Rose       PG  7317074     Detroit Pistons
# 4 1995-07-26   Marial Shayok        G    79568  Philadelphia 76ers

# %%
nba.sort_index(axis='columns').head()
# Out:
#                  Birthday Position   Salary                Team
# Name
# Shake Milton   1996-09-26       SG  1445697  Philadelphia 76ers
# Christian Wood 1995-09-27       PF  1645357     Detroit Pistons
# PJ Washington  1998-08-23       PF  3831840   Charlotte Hornets
# Derrick Rose   1988-10-04       PG  7317074     Detroit Pistons
# Marial Shayok  1995-07-26        G    79568  Philadelphia 76ers

# %% [markdown]
# - 특정 열에서 값 추출출

# %%
nba = pd.read_csv(
    "https://raw.githubusercontent.com/paskhaver/pandas-in-action/master/chapter_04_the_dataframe_object/nba.csv", parse_dates = ["Birthday"], index_col = "Name"
)

# %%
nba.loc["Giannis Antetokounmpo", "Team"]
# Out:
# 'Milwaukee Bucks'

# %%
nba.loc[
    ["Russell Westbrook", "Anthony Davis"],
    ["Team", "Salary"]
]
# Out:
#                                  Team    Salary
# Name
# Russell Westbrook     Houston Rockets  38506482
# Anthony Davis      Los Angeles Lakers  27093019

# %% [markdown]
# - DataFrame에서 단일 값을 추출할 때, loc이나 iloc대신 at과 iat이라는 두 가지 속성을 사용할 수 있습니다. 판다스는 단일 값을 찾을 때 검색 알고리즘을 최적화 할 수 있기 때문에 at과 iat가 loc이나 iloc보다 빠름.\
#
# - at 속성은 행 및 열 레이블을 허용합니다.

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4])
plt.show()

# %% [markdown]
# - 네이밍 컨벤션 -> import matplotlib.pyplot as plt
#
# - 주피터 노트북 사용시 대화형 시각화 간으

# %%
#주피터 노트북 사용시 대화형 시각화 간으

# %%
#% matplotlib notebook 
% matplotlib inline 
plt.plot([1,2,3,4])
plt.show()

#주피터 노트북에서는 바로 나옴
# Out:
# UsageError: Line magic function `%` not found.

# %%
% matplotlib inline 

plt.plot([1,2,3,4])
plt.show()

# %% [markdown]
#  - Figure/ Axes
#   - Figure 큰 툴, axes라는 서브플롯을 만들게 됨

# %%
fig = plt.figure()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig = plt.figure(figsize = (12,7)) #12인치, 7인치 
ax = fig.add_subplot()
plt.show()

# %% [markdown]
# - 2개 이상 그리고 싶다면, 위치를 지정

# %%
 fig = plt.figure()
 ax = fig.add_subplot(121) #(1,2,1)로 사용가능
 ax = fig.add_subplot(122) #(1,2,2)로 사용가능
 plt.show()

# %%
fig = plt.figure()

x1 = [4,5,6]
x2 = [6,5,4]

ax1 = fig.add_subplot(121)
plt.plot(x1)
ax2 = fig.add_subplot(122)
plt.plot(x2)
plt.show()

# %%
fig = plt.figure()


ax = fig.add_subplot(111)

ax.plot([1,1,1]) 
ax.plot([1,2,3])
ax.plot([3,2,1])

plt.show()

# %%
fig = plt.figure()


ax = fig.add_subplot(111)

ax.plot([1,1,1], color ='r') 
ax.plot([1,2,3], color = 'coral')
ax.plot([3,2,1], label ='3')

plt.show()

# %%
# matplotlib colors 
#https://matplotlib.org/stable/gallery/color/named_colors.html

#hex colors

# %%
fig = plt.figure()


ax = fig.add_subplot(111)

ax.plot([1,1,1], color ='r', label='1') 
ax.plot([1,2,3], color = 'coral', label='2')
ax.plot([3,2,1], label ='3')

ax.legend()
plt.show()

# %%
fig = plt.figure()


ax = fig.add_subplot(111)

ax.plot([1,1,1], color ='r', label='1') 
ax.plot([1,2,3], color = 'coral', label='2')
ax.plot([3,2,1], label ='3')
ax.set_title('Basic Plot')
ax.legend()
plt.show()

# %%
fig = plt.figure()


ax = fig.add_subplot(111)

ax.plot([1,1,1], color ='r', label='1') 
ax.plot([1,2,3], color = 'coral', label='2')
ax.plot([3,2,1], label ='3')

ax.set_title('Basic Plot')
ax.set_xticks([0,1])
ax.set_yticks([0,1])
ax.legend()
plt.show()

# %%
fig = plt.figure()


ax = fig.add_subplot(111)

ax.plot([1,1,1], color ='r', label='1') 
ax.plot([1,2,3], color = 'coral', label='2')
ax.plot([3,2,1], label ='3')

ax.set_title('Basic Plot')
ax.set_xticks([0,1])
ax.set_yticks([1,1])

ax.legend()
plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot(111)

ax.plot([1,1,1],label='1')
ax.plot([1,2,3],label='2') 
ax.plot([3,2,1],label='3')

ax.set_title('Basic plot')
ax.set_xticks([0,1,2])
ax.set_xticklabels(['zero','one','two'])
ax.annotate

ax.legend()
plt.show()

# %%
fig = plt.figure()

ax = fig.add_subplot(111)

ax.plot([1,1,1],label='1')
ax.plot([1,2,3],label='2') 
ax.plot([3,2,1],label='3')

ax.set_title('Basic plot')
ax.set_xticks([0,1,2])
ax.set_xticklabels(['zero','one','two'])
ax.annotate(text='This is Annotate', xy=(1, 2),
           xytext=(1.2, 2.2), 
            arrowprops=dict(facecolor='black'),
           )
ax.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

x= np.arange(-5,5,0.5)
y1 = x
y2 = x**2
y3 = np.sin(x)
y4 = np.cos(x)

plt.plot(x,y1)
plt.plot(x,y2,marker='D')
plt.plot(x,y3,color='r')
plt.plot(x,y4,linestyle='dashed')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - bar plot

# %%
data = {'사과':21, '바나나':15, '배':5,'키위':20}
names = list(data.keys())
values = list(data.values())

fig,ax = plt.subplots()

# %%
data = np.random.rand(10000)
fig, ax = plt.subplots()
ax.hist(data, bins=100, facecolor='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  - Scatter plot(산점도 그림림)

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111,aspect = 1)

np.random.seed(42)

x = np.random.rand(20)
y = np.random.rand(20)

ax.scatter(x,y)
ax.set_xlim(0,1.05)
ax.set_ylim(0,1.05)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
